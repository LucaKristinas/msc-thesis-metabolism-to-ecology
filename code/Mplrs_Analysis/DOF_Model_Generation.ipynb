# %% [markdown]
# # Import and Load Libraries

# %%
# Standard library imports
import copy         
import re            
import subprocess   
import sys
from pathlib import Path 

# Third-party library imports
import numpy as np             
import pandas as pd             
import matplotlib.pyplot as plt  

# COBRApy 
import cobra                     
from cobra import Reaction       
from cobra.io import (read_sbml_model, save_matlab_model, write_sbml_model)
from cobra.util.array import create_stoichiometric_matrix  # To build stoichiometric matrices from models

# %% [markdown]
# # Functions

# %%
# Set the project root path by going up from the notebook location
notebook_dir = Path(__file__).parent if '__file__' in globals() else Path().resolve()
project_root = notebook_dir.parent.parent  
sys.path.append(str(project_root))

# Import Helper Functions
from src.utils import (parse_quickcheck_output)

# %% [markdown]
# # Define Paths

# %%
raw_sbml_path = project_root / "data" / "raw" / "sbml_files"
temp_sbml_path = raw_sbml_path / "temporary_files"
quickcheck_path = project_root / "code"/ "Mplrs_Analysis"/ "quickcheck_sbml.py"
processed_sbml_path = project_root / "data" / "processed" / "sbml_files"

# %% [markdown]
# # Import Model

# %%
model = read_sbml_model(str(raw_sbml_path / "e_coli_core.xml"))

# %% [markdown]
# # Modify Exchange Fluxes

# %%
# Run FBA
solution = model.optimize()

# Collect data from exchange reactions
data = []
for rxn in model.exchanges:
    flux = solution.fluxes.get(rxn.id, None)
    included_in_fba = flux is not None and abs(flux) > 1e-20  # Tiny flux ≈ zero

    # Determine Export/Import values
    export = None
    import_ = None
    if included_in_fba:
        export = flux > 0
        import_ = flux < 0
    else:
        # Use bounds as heuristic if not used in FBA
        if rxn.lower_bound == 0 and rxn.upper_bound > 0:
            export = True
            import_ = False
        elif rxn.upper_bound == 0 and rxn.lower_bound < 0:
            export = False
            import_ = True

    data.append({
        'ID': rxn.id,
        'name': rxn.name,
        'LB': rxn.lower_bound,
        'UB': rxn.upper_bound,
        'FBA': included_in_fba,
        'FBA_flux': flux if included_in_fba else None,
        'Export': export,
        'Import': import_
    })

# Convert to DataFrame
exchange_df = pd.DataFrame(data)

# Sort and reset index
exchange_df.sort_values(by='ID', inplace=True)
exchange_df.reset_index(drop=True, inplace=True)

# %%
# Version 0: D-Glucose exchange (no need to produce, already there!)

# Version 1: D-Glucose exchange, D-Fructose exchange 

exchange_df.loc[exchange_df['ID'] == "EX_fru_e", 'Import'] = True
exchange_df.loc[exchange_df['ID'] == "EX_fru_e", 'Export'] = False

# Version 2: D-Fructose exchange, L-Glutamine exchange 

exchange_df.loc[exchange_df['ID'] == "EX_gln__L_e", 'Import'] = True
exchange_df.loc[exchange_df['ID'] == "EX_gln__L_e", 'Export'] = False

# Version 3: D-Fructose exchange, L-Glutamine exchange, Fumarate exchange 

exchange_df.loc[exchange_df['ID'] == "EX_fum_e", 'Import'] = True
exchange_df.loc[exchange_df['ID'] == "EX_fum_e", 'Export'] = False

# Version 4: D-Fructose exchange, L-Glutamine exchange, Fumarate exchange, L-Malate exchange 

exchange_df.loc[exchange_df['ID'] == "EX_mal__L_e", 'Import'] = True
exchange_df.loc[exchange_df['ID'] == "EX_mal__L_e", 'Export'] = False

# %%
# Check if any IDs are unassigned
missing_ids = exchange_df.loc[exchange_df['Import'].isna(), 'ID'].to_list() # all IDs assigned!

# %% [markdown]
# # Modify Directionalities

# %%
rev_model = copy.deepcopy(model)

# %%
for i, row in exchange_df.iterrows():
    rxn_id = row['ID']
    export = row['Export']
    import_ = row['Import']

    try:
        rxn = rev_model.reactions.get_by_id(rxn_id)
    except KeyError:
        continue

    original_lb = rxn.lower_bound
    original_ub = rxn.upper_bound

    # Handle Export cleanup
    if export and original_lb < 0:
        rxn.lower_bound = 0

    # Handle Import split
    elif import_:
        # Adjust original reaction bounds
        new_bound = abs(original_lb)
        rxn.lower_bound = 0
        rxn.upper_bound = new_bound

        # Create reverse reaction
        rxn_rev = Reaction(id=rxn_id + "_rev")
        rxn_rev.name = rxn.name + " (reversed)"
        rxn_rev.lower_bound = 0
        rxn_rev.upper_bound = new_bound
        rxn_rev.add_metabolites({met: -coeff for met, coeff in rxn.metabolites.items()})
        rev_model.add_reactions([rxn_rev])

        # Handle groups
        for group in rev_model.groups:
            if rxn in group.members:
                group.members.remove(rxn)
                group.members.add(rxn_rev)

        # Remove original reaction from model
        rev_model.reactions.remove(rxn)

# %%
write_sbml_model(rev_model, temp_sbml_path / 'revmodel.xml')

# %%
# Load models into a list
model_path =  temp_sbml_path / 'revmodel.xml'
models = [read_sbml_model(model_path) for _ in range(5)]

# Define which extra exchanges each model version should allow
# (besides D-glucose which is already present)
exchange_config = {
    1: ["EX_fru_e_rev"],
    2: ["EX_fru_e_rev", "EX_gln__L_e_rev"],
    3: ["EX_fru_e_rev", "EX_gln__L_e_rev", "EX_fum_e_rev"],
    4: ["EX_fru_e_rev", "EX_gln__L_e_rev", "EX_fum_e_rev", "EX_mal__L_e_rev"]
}

# Apply exchange bounds (0 to 5) to the specified reactions
for i, rxn_ids in exchange_config.items():
    for rxn_id in rxn_ids:
        rxn = models[i].reactions.get_by_id(rxn_id)
        rxn.lower_bound = 0
        rxn.upper_bound = 5

# Save each model in the models list with a corresponding filename
for i, model in enumerate(models):
    filename = temp_sbml_path/ f"model_v{i}_quickcheck.xml"
    write_sbml_model(model, filename)

# %%
# Run FBA for each model and collect results
results = []

for i, model in enumerate(models):
    solution = model.optimize()  # or pfba(model) if you prefer parsimonious FBA
    results.append({
        "version": f"v{i}",
        "objective_value": solution.objective_value
        # You can add more if needed, like specific fluxes below
        # "EX_glc__D_e": solution.fluxes.get("EX_glc__D_e", None)
    })

# Convert to DataFrame
fba_df = pd.DataFrame(results)

# %% [markdown]
# # Integrate QuickCheck Results

# %%
# Loop over model versions v0 to v4
for i in range(5):
    model_file = f"{temp_sbml_path}/model_v{i}_quickcheck.xml"
    command = ["python", quickcheck_path, "-s", model_file]
    
    print(f"Running quickcheck for model_v{i}...")
    subprocess.run(command)
# Out:
# Running quickcheck for model_v0...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  39
# metabolites: 72
# genes: 137
# growth rate: 0.8739215069684295
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v0_quickcheck_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PGK: 3pg_c + atp_c <=> 13dpg_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -19.7676854458 FVA maximum: -1.0959150482 difference: 18.671770397600003
# reversibility: True
# ------------------------------------------------
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# AKGt2r: akg_e + h_e <=> akg_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -9.3358851988 FVA maximum: 0.0 difference: 9.3358851988
# reversibility: True
# ------------------------------------------------
# PGM: 2pg_c <=> 3pg_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -19.6369467884 FVA maximum: -0.9651763907 difference: 18.671770397699998
# reversibility: True
# ------------------------------------------------
# PIt2r: h_e + pi_e <=> h_c + pi_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.3214895048 FVA maximum: 3.2148950477 difference: 2.8934055428999996
# reversibility: True
# ------------------------------------------------
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ACALDt: acald_e <=> acald_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ACKr: ac_c + atp_c <=> actp_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ACONTa: cit_c <=> acon_C_c + h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0942873914 FVA maximum: 18.766057789 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ACONTb: acon_C_c + h2o_c <=> icit_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0942873914 FVA maximum: 18.766057789 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ACt2r: ac_e + h_e <=> ac_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ADK1: amp_c + atp_c <=> 2.0 adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 150.1556660394 difference: 150.1556660394
# reversibility: True
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 18.6717703976 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# PYRt2: h_e + pyr_e <=> h_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# CO2t: co2_e <=> co2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -56.280983331 FVA maximum: 0.0 difference: 56.280983331
# reversibility: True
# ------------------------------------------------
# RPI: r5p_c <=> ru5p__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.7345878756 FVA maximum: -0.0628174779 difference: 18.671770397699998
# reversibility: True
# ------------------------------------------------
# D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# ENO: 2pg_c <=> h2o_c + pep_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.9651763907 FVA maximum: 19.6369467884 difference: 18.671770397699998
# reversibility: True
# ------------------------------------------------
# ETOHt2r: etoh_e + h_e <=> etoh_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# FORt: for_e <-- for_c
# lower bound: -1000.0 upper bound: 0.0
# FVA minimum: -600.6226641574 FVA maximum: 0.0 difference: 600.6226641574
# reversibility: False
# ------------------------------------------------
# FRUpts2: fru_e + pep_c --> f6p_c + pyr_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# FUMt2_2: fum_e + 2.0 h_e --> fum_c + 2.0 h_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 56.0153111929 difference: 56.0153111929
# reversibility: True
# ------------------------------------------------
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 1.0959150482 FVA maximum: 19.7676854458 difference: 18.671770397600003
# reversibility: True
# ------------------------------------------------
# GLNabc: atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# GLUt2r: glu__L_e + h_e <=> glu__L_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -9.3358851988 FVA maximum: 0.0 difference: 9.3358851988
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -56.9175827136 FVA maximum: 0.0 difference: 56.9175827136
# reversibility: True
# ------------------------------------------------
# ICDHyr: icit_c + nadp_c <=> akg_c + co2_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0942873914 FVA maximum: 18.766057789 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.6717703976 FVA maximum: 0.0 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# MALt2_2: 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# NH4t: nh4_e <=> nh4_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.4765319193 FVA maximum: 9.8124171181 difference: 9.335885198800002
# reversibility: True
# ------------------------------------------------
# O2t: o2_e <=> o2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 56.1799492656 difference: 56.1799492656
# reversibility: True
# ------------------------------------------------
# EX_fru_e_rev:  --> fru_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# EX_fum_e_rev:  --> fum_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# EX_gln__L_e_rev:  --> gln__L_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# EX_mal__L_e_rev:  --> mal__L_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v1...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  39
# metabolites: 72
# genes: 137
# growth rate: 1.3322452388439525
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v1_quickcheck_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PGK: 3pg_c + atp_c <=> 13dpg_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.6458492482 FVA maximum: -1.6706621744 difference: 27.9751870738
# reversibility: True
# ------------------------------------------------
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# AKGt2r: akg_e + h_e <=> akg_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -13.9875935369 FVA maximum: 0.0 difference: 13.9875935369
# reversibility: True
# ------------------------------------------------
# PGM: 2pg_c <=> 3pg_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.4465453604 FVA maximum: -1.4713582867 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# PIt2r: h_e + pi_e <=> h_c + pi_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.490093056 FVA maximum: 4.9009305601 difference: 4.4108375041
# reversibility: True
# ------------------------------------------------
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# ACALDt: acald_e <=> acald_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# ACKr: ac_c + atp_c <=> actp_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# ACONTa: cit_c <=> acon_C_c + h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.1437359388 FVA maximum: 28.1189230126 difference: 27.9751870738
# reversibility: True
# ------------------------------------------------
# ACONTb: acon_C_c + h2o_c <=> icit_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.1437359388 FVA maximum: 28.1189230126 difference: 27.9751870738
# reversibility: True
# ------------------------------------------------
# ACt2r: ac_e + h_e <=> ac_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# ADK1: amp_c + atp_c <=> 2.0 adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 229.0262734838 difference: 229.0262734838
# reversibility: True
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 27.9751870737 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# PYRt2: h_e + pyr_e <=> h_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# CO2t: co2_e <=> co2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -84.3305637738 FVA maximum: 0.0 difference: 84.3305637738
# reversibility: True
# ------------------------------------------------
# RPI: r5p_c <=> ru5p__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.0709488615 FVA maximum: -0.0957617878 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# ENO: 2pg_c <=> h2o_c + pep_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 1.4713582867 FVA maximum: 29.4465453604 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# ETOHt2r: etoh_e + h_e <=> etoh_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# FORt: for_e <-- for_c
# lower bound: -1000.0 upper bound: 0.0
# FVA minimum: -916.1050939352 FVA maximum: 0.0 difference: 916.1050939352
# reversibility: False
# ------------------------------------------------
# FUMt2_2: fum_e + 2.0 h_e --> fum_c + 2.0 h_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 83.9255612212 difference: 83.9255612212
# reversibility: True
# ------------------------------------------------
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 1.6706621744 FVA maximum: 29.6458492482 difference: 27.9751870738
# reversibility: True
# ------------------------------------------------
# GLNabc: atp_c + gln__L_e + h2o_c --> adp_c + gln__L_c + h_c + pi_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# GLUt2r: glu__L_e + h_e <=> glu__L_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -13.9875935369 FVA maximum: 0.0 difference: 13.9875935369
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -85.3010244956 FVA maximum: 0.0 difference: 85.3010244956
# reversibility: True
# ------------------------------------------------
# ICDHyr: icit_c + nadp_c <=> akg_c + co2_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.1437359388 FVA maximum: 28.1189230126 difference: 27.9751870738
# reversibility: True
# ------------------------------------------------
# LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -27.9751870737 FVA maximum: 0.0 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# MALt2_2: 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# NH4t: nh4_e <=> nh4_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.7264466838 FVA maximum: 14.7140402207 difference: 13.987593536899999
# reversibility: True
# ------------------------------------------------
# O2t: o2_e <=> o2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 84.1765429018 difference: 84.1765429018
# reversibility: True
# ------------------------------------------------
# EX_fum_e_rev:  --> fum_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# EX_gln__L_e_rev:  --> gln__L_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# EX_mal__L_e_rev:  --> mal__L_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v2...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  39
# metabolites: 72
# genes: 137
# growth rate: 1.6213775666569172
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v2_quickcheck_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PGK: 3pg_c + atp_c <=> 13dpg_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.5689892015 FVA maximum: -1.4162570907 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# AKGt2r: akg_e + h_e <=> akg_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -14.2099270324 FVA maximum: 0.0 difference: 14.2099270324
# reversibility: True
# ------------------------------------------------
# PGM: 2pg_c <=> 3pg_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.3264311175 FVA maximum: -1.1736990067 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# PIt2r: h_e + pi_e <=> h_c + pi_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.5964561654 FVA maximum: 5.9645616545 difference: 5.3681054890999995
# reversibility: True
# ------------------------------------------------
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ACALDt: acald_e <=> acald_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ACKr: ac_c + atp_c <=> actp_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ACONTa: cit_c <=> acon_C_c + h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 28.1527321108 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ACONTb: acon_C_c + h2o_c <=> icit_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 28.1527321108 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ACt2r: ac_e + h_e <=> ac_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ADK1: amp_c + atp_c <=> 2.0 adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 229.0390440312 difference: 229.0390440312
# reversibility: True
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 28.1527321108 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# PYRt2: h_e + pyr_e <=> h_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# CO2t: co2_e <=> co2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -85.3104085951 FVA maximum: 0.0 difference: 85.3104085951
# reversibility: True
# ------------------------------------------------
# RPI: r5p_c <=> ru5p__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.2692767302 FVA maximum: -0.1165446195 difference: 28.1527321107
# reversibility: True
# ------------------------------------------------
# D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ENO: 2pg_c <=> h2o_c + pep_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 1.1736990067 FVA maximum: 29.3264311175 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# ETOHt2r: etoh_e + h_e <=> etoh_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.4198540649 FVA maximum: 0.0 difference: 28.4198540649
# reversibility: True
# ------------------------------------------------
# FORt: for_e <-- for_c
# lower bound: -1000.0 upper bound: 0.0
# FVA minimum: -916.1561761247 FVA maximum: 0.0 difference: 916.1561761247
# reversibility: False
# ------------------------------------------------
# FUMt2_2: fum_e + 2.0 h_e --> fum_c + 2.0 h_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 84.4581963323 difference: 84.4581963323
# reversibility: True
# ------------------------------------------------
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 1.4162570907 FVA maximum: 29.5689892015 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# GLUt2r: glu__L_e + h_e <=> glu__L_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.7678746527 FVA maximum: 0.0 difference: 18.7678746527
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -85.1653277304 FVA maximum: 0.0 difference: 85.1653277304
# reversibility: True
# ------------------------------------------------
# LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -28.1527321108 FVA maximum: 0.0 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# MALt2_2: 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# NH4t: nh4_e <=> nh4_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 14.6519794122 difference: 14.6519794122
# reversibility: True
# ------------------------------------------------
# O2t: o2_e <=> o2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 84.9019349447 difference: 84.9019349447
# reversibility: True
# ------------------------------------------------
# EX_fum_e_rev:  --> fum_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# EX_mal__L_e_rev:  --> mal__L_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v3...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  39
# metabolites: 72
# genes: 137
# growth rate: 1.8707706140634688
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v3_quickcheck_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -32.868593624 FVA maximum: 0.0 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# AKGt2r: akg_e + h_e <=> akg_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -16.5884015413 FVA maximum: 0.0 difference: 16.5884015413
# reversibility: True
# ------------------------------------------------
# PIt2r: h_e + pi_e <=> h_c + pi_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.6882003858 FVA maximum: 6.882003858 difference: 6.1938034722
# reversibility: True
# ------------------------------------------------
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.0514507037 FVA maximum: 0.0 difference: 29.0514507037
# reversibility: True
# ------------------------------------------------
# ACALDt: acald_e <=> acald_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -32.868593624 FVA maximum: 0.0 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# ACKr: ac_c + atp_c <=> actp_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -32.868593624 FVA maximum: 0.0 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# ACONTa: cit_c <=> acon_C_c + h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 32.868593624 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# ACONTb: acon_C_c + h2o_c <=> icit_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 32.868593624 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# ACt2r: ac_e + h_e <=> ac_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -32.868593624 FVA maximum: 0.0 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# ADK1: amp_c + atp_c <=> 2.0 adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 253.0577908914 difference: 253.0577908914
# reversibility: True
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 32.868593624 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# PYRt2: h_e + pyr_e <=> h_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -32.868593624 FVA maximum: 0.0 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# CO2t: co2_e <=> co2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -97.3217486658 FVA maximum: 0.0 difference: 97.3217486658
# reversibility: True
# ------------------------------------------------
# RPI: r5p_c <=> ru5p__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.8740690761 FVA maximum: -0.1344709917 difference: 29.7395980844
# reversibility: True
# ------------------------------------------------
# D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -31.4738933533 FVA maximum: 0.0 difference: 31.4738933533
# reversibility: True
# ------------------------------------------------
# ETOHt2r: etoh_e + h_e <=> etoh_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.0514507037 FVA maximum: 0.0 difference: 29.0514507037
# reversibility: True
# ------------------------------------------------
# SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -33.1768030827 FVA maximum: 0.0 difference: 33.1768030827
# reversibility: True
# ------------------------------------------------
# FORt: for_e <-- for_c
# lower bound: -1000.0 upper bound: 0.0
# FVA minimum: -1000.0 FVA maximum: 0.0 difference: 1000.0
# reversibility: False
# ------------------------------------------------
# G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 89.2187942531 difference: 89.2187942531
# reversibility: True
# ------------------------------------------------
# GLUt2r: glu__L_e + h_e <=> glu__L_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -21.0783546411 FVA maximum: 0.0 difference: 21.0783546411
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -87.1543521112 FVA maximum: 0.0 difference: 87.1543521112
# reversibility: True
# ------------------------------------------------
# LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -31.4738933533 FVA maximum: 0.0 difference: 31.4738933533
# reversibility: True
# ------------------------------------------------
# MALt2_2: 2.0 h_e + mal__L_e --> 2.0 h_c + mal__L_c
# lower bound: 0.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# NH4t: nh4_e <=> nh4_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 17.0984484415 difference: 17.0984484415
# reversibility: True
# ------------------------------------------------
# O2t: o2_e <=> o2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 95.4841093993 difference: 95.4841093993
# reversibility: True
# ------------------------------------------------
# EX_mal__L_e_rev:  --> mal__L_e
# lower bound: 0.0 upper bound: 0.0
# FVA minimum: 0.0 FVA maximum: 0.0 difference: 0.0
# reversibility: False
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v4...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  39
# metabolites: 72
# genes: 137
# growth rate: 2.083440205173316
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v4_quickcheck_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# ACALD: acald_c + coa_c + nad_c <=> accoa_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.6262949054 FVA maximum: 0.0 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# AKGt2r: akg_e + h_e <=> akg_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -18.9847708396 FVA maximum: 0.0 difference: 18.9847708396
# reversibility: True
# ------------------------------------------------
# PIt2r: h_e + pi_e <=> h_c + pi_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.7664351483 FVA maximum: 7.6643514828 difference: 6.8979163345
# reversibility: True
# ------------------------------------------------
# ALCD2x: etoh_c + nad_c <=> acald_c + h_c + nadh_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -30.6102860898 FVA maximum: 0.0 difference: 30.6102860898
# reversibility: True
# ------------------------------------------------
# ACALDt: acald_e <=> acald_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.6262949054 FVA maximum: 0.0 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# ACKr: ac_c + atp_c <=> actp_c + adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.6262949054 FVA maximum: 0.0 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# ACONTa: cit_c <=> acon_C_c + h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 37.6262949054 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# ACONTb: acon_C_c + h2o_c <=> icit_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 37.6262949054 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# ACt2r: ac_e + h_e <=> ac_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.6262949054 FVA maximum: 0.0 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# ADK1: amp_c + atp_c <=> 2.0 adp_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 273.9882706199 difference: 273.9882706199
# reversibility: True
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 37.6262949054 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# PYRt2: h_e + pyr_e <=> h_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.6262949054 FVA maximum: 0.0 difference: 37.6262949054
# reversibility: True
# ------------------------------------------------
# CO2t: co2_e <=> co2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -107.0172844991 FVA maximum: 0.0 difference: 107.0172844991
# reversibility: True
# ------------------------------------------------
# RPI: r5p_c <=> ru5p__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -29.8597532226 FVA maximum: -0.1497576819 difference: 29.7099955407
# reversibility: True
# ------------------------------------------------
# D_LACt2: h_e + lac__D_e <=> h_c + lac__D_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -36.262511831 FVA maximum: 0.0 difference: 36.262511831
# reversibility: True
# ------------------------------------------------
# ETOHt2r: etoh_e + h_e <=> etoh_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -30.6102860898 FVA maximum: 0.0 difference: 30.6102860898
# reversibility: True
# ------------------------------------------------
# SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.9695416792 FVA maximum: 0.0 difference: 37.9695416792
# reversibility: True
# ------------------------------------------------
# FORt: for_e <-- for_c
# lower bound: -1000.0 upper bound: 0.0
# FVA minimum: -1000.0 FVA maximum: 0.0 difference: 1000.0
# reversibility: False
# ------------------------------------------------
# G6PDH2r: g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 89.1299866219 difference: 89.1299866219
# reversibility: True
# ------------------------------------------------
# GLUt2r: glu__L_e + h_e <=> glu__L_c + h_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -23.4167417021 FVA maximum: 0.0 difference: 23.4167417021
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -91.8308582695 FVA maximum: 0.0 difference: 91.8308582695
# reversibility: True
# ------------------------------------------------
# LDH_D: lac__D_c + nad_c <=> h_c + nadh_c + pyr_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -36.262511831 FVA maximum: 0.0 difference: 36.262511831
# reversibility: True
# ------------------------------------------------
# NH4t: nh4_e <=> nh4_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 19.5527999772 difference: 19.5527999772
# reversibility: True
# ------------------------------------------------
# O2t: o2_e <=> o2_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 104.9707420199 difference: 104.9707420199
# reversibility: True
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt

# %% [markdown]
# ### Round 1

# %%
# Loop over model versions v0 to v4
for i in range(5):
    print(f"\n🔧 Processing model_v{i}...")

    # Load model
    model_path = f"{temp_sbml_path}/model_v{i}_quickcheck.xml"
    qc_model = read_sbml_model(model_path)

    # Load quickcheck reaction data
    df_path = f"{temp_sbml_path}/model_v{i}_quickcheck_reactions.txt"
    quickcheck_df = parse_quickcheck_output(df_path)

    # Identify reaction sets
    irrev_list_fwd = quickcheck_df[(quickcheck_df['min'] >= 0) & (quickcheck_df['lb'] < 0)].reaction_id.tolist()
    irrev_list_rev = quickcheck_df[(quickcheck_df['min'] < 0) & (quickcheck_df['max'] <= 0)].reaction_id.tolist()
    delete_list = quickcheck_df[(quickcheck_df['min'] == 0) & (quickcheck_df['max'] == 0)].reaction_id.tolist()

    # 🗑️ Delete blocked reactions
    success_count = 0
    for rxn_id in delete_list:
        try:
            rxn = qc_model.reactions.get_by_id(rxn_id)
            for group in qc_model.groups:
                if rxn in group.members:
                    group.members.remove(rxn)
            metabolites = list(rxn.metabolites.keys())
            qc_model.reactions.remove(rxn)
            for met in metabolites:
                if len(met.reactions) == 0:
                    qc_model.metabolites.remove(met)
            success_count += 1
        except KeyError:
            continue
    print(f"✅ Deleted {success_count} blocked reactions.")

    # 🔁 Process reverse-only irreversible reactions
    success_count = 0
    for rxn_id in irrev_list_rev:
        try:
            rxn = qc_model.reactions.get_by_id(rxn_id)
        except KeyError:
            continue
        new_bound = abs(rxn.lower_bound)
        rxn.lower_bound = 0
        rxn.upper_bound = new_bound
        rxn_rev = Reaction(id=rxn_id + "_rev")
        rxn_rev.name = rxn.name + " (reversed)"
        rxn_rev.lower_bound = 0
        rxn_rev.upper_bound = new_bound
        rxn_rev.add_metabolites({met: -coeff for met, coeff in rxn.metabolites.items()})
        qc_model.add_reactions([rxn_rev])
        for group in qc_model.groups:
            if rxn in group.members:
                group.members.remove(rxn)
                group.members.add(rxn_rev)
        qc_model.reactions.remove(rxn)
        success_count += 1
    print(f"✅ Reversed and replaced {success_count} reverse-only reactions.")

    # ➡️ Adjust forward-only irreversible reactions
    success_count = 0
    for rxn_id in irrev_list_fwd:
        try:
            rxn = qc_model.reactions.get_by_id(rxn_id)
            rxn.lower_bound = 0
            success_count += 1
        except KeyError:
            continue
    print(f"✅ Updated {success_count} forward-only reactions (set lb to 0).")

    # 💾 Save modified model
    export_path = f"{temp_sbml_path}/model_v{i}_quickcheck2.xml"
    write_sbml_model(qc_model, export_path)
    print(f"💾 Saved modified model to {export_path}")
# Out:
# 🔧 Processing model_v0...
# ✅ Deleted 8 blocked reactions.
# ✅ Reversed and replaced 17 reverse-only reactions.
# ✅ Updated 10 forward-only reactions (set lb to 0).
# 💾 Saved modified model to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v0_quickcheck2.xml
#
# 🔧 Processing model_v1...
# ✅ Deleted 6 blocked reactions.
# ✅ Reversed and replaced 17 reverse-only reactions.
# ✅ Updated 10 forward-only reactions (set lb to 0).
# 💾 Saved modified model to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v1_quickcheck2.xml
#
# 🔧 Processing model_v2...
# ✅ Deleted 4 blocked reactions.
# ✅ Reversed and replaced 17 reverse-only reactions.
# ✅ Updated 9 forward-only reactions (set lb to 0).
# 💾 Saved modified model to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v2_quickcheck2.xml
#
# 🔧 Processing model_v3...
# ✅ Deleted 2 blocked reactions.
# ✅ Reversed and replaced 16 reverse-only reactions.
# ✅ Updated 7 forward-only reactions (set lb to 0).
# 💾 Saved modified model to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v3_quickcheck2.xml
#
# 🔧 Processing model_v4...
# ✅ Deleted 0 blocked reactions.
# ✅ Reversed and replaced 13 reverse-only reactions.
# ✅ Updated 8 forward-only reactions (set lb to 0).
# 💾 Saved modified model to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v4_quickcheck2.xml

# %% [markdown]
# ### Round 2

# %%
# Loop over model versions v0 to v4
for i in range(5):
    model_file = f"{temp_sbml_path}/model_v{i}_quickcheck2.xml"
    command = ["python", quickcheck_path, "-s", model_file]
    
    print(f"Running quickcheck for model_v{i}...")
    subprocess.run(command)
# Out:
# Running quickcheck for model_v0...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 87 (including reactions added by cobrapy)
# reversibilities:  13
# metabolites: 72
# genes: 137
# growth rate: 0.8739215069684311
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v0_quickcheck2_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 18.6717703976 difference: 18.6717703976
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -56.9175827136 FVA maximum: 0.0 difference: 56.9175827136
# reversibility: True
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v1...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 89 (including reactions added by cobrapy)
# reversibilities:  13
# metabolites: 72
# genes: 137
# growth rate: 1.332245238843957
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v1_quickcheck2_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 27.9751870737 difference: 27.9751870737
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -85.3010244956 FVA maximum: 0.0 difference: 85.3010244956
# reversibility: True
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v2...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 91 (including reactions added by cobrapy)
# reversibilities:  14
# metabolites: 72
# genes: 137
# growth rate: 1.621377566656926
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v2_quickcheck2_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 28.1527321108 difference: 28.1527321108
# reversibility: True
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -85.1653277304 FVA maximum: 0.0 difference: 85.1653277304
# reversibility: True
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v3...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 93 (including reactions added by cobrapy)
# reversibilities:  17
# metabolites: 72
# genes: 137
# growth rate: 1.8707706140634617
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v3_quickcheck2_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# PTAr: accoa_c + pi_c <=> actp_c + coa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: 0.0 FVA maximum: 32.868593624 difference: 32.868593624
# reversibility: True
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# Running quickcheck for model_v4...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  18
# metabolites: 72
# genes: 137
# growth rate: 2.0834402051733067
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v4_quickcheck2_reactions.txt
# ------------------------------------------------
# Please check the following reactions:
# NOTE: FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt
# ------------------------------------------------
# SUCOAS: atp_c + coa_c + succ_c <=> adp_c + pi_c + succoa_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -37.9695416792 FVA maximum: 0.0 difference: 37.9695416792
# reversibility: True
# ------------------------------------------------
# FORt: for_e <-- for_c
# lower bound: -1000.0 upper bound: 0.0
# FVA minimum: -1000.0 FVA maximum: 0.0 difference: 1000.0
# reversibility: False
# ------------------------------------------------
# H2Ot: h2o_e <=> h2o_c
# lower bound: -1000.0 upper bound: 1000.0
# FVA minimum: -91.8308582695 FVA maximum: 0.0 difference: 91.8308582695
# reversibility: True
# ------------------------------------------------
# FVA results are rounded to 10th decimal, exact values can be found in *_reactions.txt

# %%
# Define version-specific reaction lists
irrev_lists_rev = {
    0: ['H2Ot'],
    1: ['H2Ot'],
    2: ['H2Ot'],
    3: [],  # v3 has none
    4: ['SUCOAS', 'FORt', 'H2Ot']
}

irrev_lists_fwd = {
    0: ['PTAr'],
    1: ['PTAr'],
    2: ['PTAr'],
    3: ['PTAr'],  # Note: was labeled as v4 in your input, corrected here
    4: []  # v4 has none
}

# Process each model v0 to v4
for i in range(5):
    print(f"\n🔧 Processing model_v{i}_quickcheck2.xml")

    # Load model
    model_path = f"{temp_sbml_path}/model_v{i}_quickcheck2.xml"
    qc_model2 = read_sbml_model(model_path)

    # Get version-specific reaction lists
    irrev_list_rev = irrev_lists_rev[i]
    irrev_list_fwd = irrev_lists_fwd[i]

    # 🔁 Process reverse-only irreversible reactions
    success_count = 0
    for rxn_id in irrev_list_rev:
        try:
            rxn = qc_model2.reactions.get_by_id(rxn_id)
        except KeyError:
            continue
        new_bound = abs(rxn.lower_bound)
        rxn.lower_bound = 0
        rxn.upper_bound = new_bound

        rxn_rev = Reaction(id=rxn_id + "_rev")
        rxn_rev.name = rxn.name + " (reversed)"
        rxn_rev.lower_bound = 0
        rxn_rev.upper_bound = new_bound
        rxn_rev.add_metabolites({met: -coeff for met, coeff in rxn.metabolites.items()})
        qc_model2.add_reactions([rxn_rev])

        for group in qc_model2.groups:
            if rxn in group.members:
                group.members.remove(rxn)
                group.members.add(rxn_rev)

        qc_model2.reactions.remove(rxn)
        success_count += 1
    print(f"✅ Reversed and replaced {success_count} reactions from 'irrev_list_rev'.")

    # ➡️ Adjust forward-only irreversible reactions
    success_count = 0
    for rxn_id in irrev_list_fwd:
        try:
            rxn = qc_model2.reactions.get_by_id(rxn_id)
            rxn.lower_bound = 0
            success_count += 1
        except KeyError:
            continue
    print(f"✅ Set lower bound to 0 for {success_count} reactions from 'irrev_list_fwd'.")

    # Save the modified model
    output_path = f"{temp_sbml_path}/model_v{i}_quickcheck3.xml"
    write_sbml_model(qc_model2, output_path)
    print(f"💾 Saved model to: {output_path}")
# Out:
# 🔧 Processing model_v0_quickcheck2.xml
# ✅ Reversed and replaced 1 reactions from 'irrev_list_rev'.
# ✅ Set lower bound to 0 for 1 reactions from 'irrev_list_fwd'.
# 💾 Saved model to: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v0_quickcheck3.xml
#
# 🔧 Processing model_v1_quickcheck2.xml
# ✅ Reversed and replaced 1 reactions from 'irrev_list_rev'.
# ✅ Set lower bound to 0 for 1 reactions from 'irrev_list_fwd'.
# 💾 Saved model to: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v1_quickcheck3.xml
#
# 🔧 Processing model_v2_quickcheck2.xml
# ✅ Reversed and replaced 1 reactions from 'irrev_list_rev'.
# ✅ Set lower bound to 0 for 1 reactions from 'irrev_list_fwd'.
# 💾 Saved model to: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v2_quickcheck3.xml
#
# 🔧 Processing model_v3_quickcheck2.xml
# ✅ Reversed and replaced 0 reactions from 'irrev_list_rev'.
# ✅ Set lower bound to 0 for 1 reactions from 'irrev_list_fwd'.
# 💾 Saved model to: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v3_quickcheck3.xml
#
# 🔧 Processing model_v4_quickcheck2.xml
# ✅ Reversed and replaced 3 reactions from 'irrev_list_rev'.
# ✅ Set lower bound to 0 for 0 reactions from 'irrev_list_fwd'.
# 💾 Saved model to: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v4_quickcheck3.xml

# %% [markdown]
# ### Round 3

# %%
# Loop over model versions v0 to v4
for i in range(5):
    model_file = f"{temp_sbml_path}/model_v{i}_quickcheck3.xml"
    command = ["python", quickcheck_path, "-s", model_file]
    
    print(f"Running quickcheck for model_v{i}...")
    subprocess.run(command)
# Out:
# Running quickcheck for model_v0...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 87 (including reactions added by cobrapy)
# reversibilities:  11
# metabolites: 72
# genes: 137
# growth rate: 0.8739215069684311
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v0_quickcheck3_reactions.txt
# ------------------------------------------------
# All reactions seem to be fine
# Exact FVA results can be found in *_reactions.txt
# Running quickcheck for model_v1...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 89 (including reactions added by cobrapy)
# reversibilities:  11
# metabolites: 72
# genes: 137
# growth rate: 1.332245238843957
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v1_quickcheck3_reactions.txt
# ------------------------------------------------
# All reactions seem to be fine
# Exact FVA results can be found in *_reactions.txt
# Running quickcheck for model_v2...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 91 (including reactions added by cobrapy)
# reversibilities:  12
# metabolites: 72
# genes: 137
# growth rate: 1.621377566656926
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v2_quickcheck3_reactions.txt
# ------------------------------------------------
# All reactions seem to be fine
# Exact FVA results can be found in *_reactions.txt
# Running quickcheck for model_v3...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 93 (including reactions added by cobrapy)
# reversibilities:  16
# metabolites: 72
# genes: 137
# growth rate: 1.8707706140634617
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v3_quickcheck3_reactions.txt
# ------------------------------------------------
# All reactions seem to be fine
# Exact FVA results can be found in *_reactions.txt
# Running quickcheck for model_v4...
# ------------------------------------------------
# COBRAPY added 0 exchange reaction
# ------------------------------------------------
# None
# reactions: 95 (including reactions added by cobrapy)
# reversibilities:  16
# metabolites: 72
# genes: 137
# growth rate: 2.0834402051733067
# ------------------------------------------------
# fraction of optimum: 0.1
# ------------------------------------------------
# Calculating FVA...
# Checking reactions...
# Writing results to file: /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/raw/sbml_files/temporary_files/model_v4_quickcheck3_reactions.txt
# ------------------------------------------------
# All reactions seem to be fine
# Exact FVA results can be found in *_reactions.txt

# %% [markdown]
# ### Information on models passed on to EFMlrs

# %%
# 📊 Collect and print summary stats for all modified models
model_stats = []

print("\n📊 Model Summary (After Modifications):")

for i in range(5):
    model_path = temp_sbml_path / f"model_v{i}_quickcheck3.xml"
    model = read_sbml_model(model_path)

    stoich = create_stoichiometric_matrix(model)
    rank = np.linalg.matrix_rank(stoich)
    num_rxns = len(model.reactions)
    num_exchanges = sum(1 for r in model.reactions if r.id.startswith("EX_"))
    dof = num_rxns - rank

    model_stats.append({
        "Model": f"model_v{i}",
        "Reactions": num_rxns,
        "Exchange Reactions": num_exchanges,
        "Rank": rank,
        "Degrees of Freedom": dof
    })

# 🖨️ Pretty print summary
print("{:<10} {:<12} {:<20} {:<8} {:<20}".format("Model", "Reactions", "Exchange Reactions", "Rank", "Degrees of Freedom"))
for stat in model_stats:
    print("{:<10} {:<12} {:<20} {:<8} {:<20}".format(
        stat["Model"],
        stat["Reactions"],
        stat["Exchange Reactions"],
        stat["Rank"],
        stat["Degrees of Freedom"]
    ))
# Out:
# 📊 Model Summary (After Modifications):
# Model      Reactions    Exchange Reactions   Rank     Degrees of Freedom
# model_v0   87           16                   63       24
# model_v1   89           17                   64       25
# model_v2   91           18                   65       26
# model_v3   93           19                   66       27
# model_v4   95           20                   67       28

# %% [markdown]
# # Export stuff for EFMlrs

# %%
# Conda environment name (replace with your actual environment)
conda_env_name = "efmlrs-env"  # change this to your environment name

# Loop through all model versions v0 to v4
for i in range(5):
    # Load the model
    model_path = f"{temp_sbml_path}/model_v{i}_quickcheck3.xml"
    model = read_sbml_model(model_path)

    # Export to Ecoli_Stuff directory
    export_path = f"{processed_sbml_path}/ecolicore_model_v{i}.xml"
    write_sbml_model(model, export_path)
    print(f"✅ Exported model_v{i} to {export_path}")

    # Command to run efmlrs_pre
    cmd = f"conda run -n {conda_env_name} efmlrs_pre -i {export_path} --bounds"

    print(f"🚀 Running efmlrs_pre on ecolicore_model_v{i}.xml...")
    subprocess.run(cmd, shell=True)
# Out:
# ✅ Exported model_v0 to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/processed/sbml_files/ecolicore_model_v0.xml
# 🚀 Running efmlrs_pre on ecolicore_model_v0.xml...
#
#            EFMlrs     __
#     (\   .-.   .-.   /_")
#      \\_//^\\_//^\\_//
#       `"´   `"´   `"´
#      start compressions
#
# Ignoring compartments: None
# The following metabolites are orphans (not involved in any reaction) and will be removed from the model
# ['gln__L_e', 'mal__L_e', 'fru_e', 'fum_e']
# no empty reactions
# Checking for additional bounds
# Found 2 additional bounds:
# Lower bound: 8.39 for reaction ATPM
# Upper bound: 10.0 for reaction EX_glc__D_e_rev
# Uncompressed network size: 90 reactions ( 11 reversible ) and 70 metabolites.
# ========================================================================
# START COMPRESSIONS
# *** Compression round: 1 ***
# Start deadend compression...
# Done deadend compression. Network size: 70 metabolites and 90 reactions ( 11 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 34 metabolites and 54 reactions ( 11 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Start null space compressions round 2 . This may take a while
# Done nullspace compression. Network size: 32 metabolites and 51 reactions ( 11 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Start reduced row echelon form calculations 2 . This may take a while
# Done echelon compression. Network size: 26 metabolites and 51 reactions ( 11 reversible )
# *** Compression round: 2 ***
# Start deadend compression...
# Done deadend compression. Network size: 26 metabolites and 51 reactions ( 11 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 26 metabolites and 51 reactions ( 11 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Done nullspace compression. Network size: 26 metabolites and 51 reactions ( 11 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Done echelon compression. Network size: 26 metabolites and 51 reactions ( 11 reversible )
# *** COMPRESSIONS DONE after: 2 rounds ***
# ========================================================================
# Compressed network size: 51 reactions ( 9 reversible ) and 26 metabolites.
# Writing files
#
#                     .-.
#                   /  oo
#    EFMlrs         \ -,_)
#              _..._| \ `-<
#         {} ." .__.\' |
#        {} (         /`\
#        {}(`´------´   /
#           `----------´
#    finished compressions
#
#
# ✅ Exported model_v1 to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/processed/sbml_files/ecolicore_model_v1.xml
# 🚀 Running efmlrs_pre on ecolicore_model_v1.xml...
#
#            EFMlrs     __
#     (\   .-.   .-.   /_")
#      \\_//^\\_//^\\_//
#       `"´   `"´   `"´
#      start compressions
#
# Ignoring compartments: None
# The following metabolites are orphans (not involved in any reaction) and will be removed from the model
# ['gln__L_e', 'mal__L_e', 'fum_e']
# no empty reactions
# Checking for additional bounds
# Found 3 additional bounds:
# Lower bound: 8.39 for reaction ATPM
# Upper bound: 5.0 for reaction EX_fru_e_rev
# Upper bound: 10.0 for reaction EX_glc__D_e_rev
# Uncompressed network size: 93 reactions ( 11 reversible ) and 72 metabolites.
# ========================================================================
# START COMPRESSIONS
# *** Compression round: 1 ***
# Start deadend compression...
# Done deadend compression. Network size: 72 metabolites and 93 reactions ( 11 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 35 metabolites and 56 reactions ( 11 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Start null space compressions round 2 . This may take a while
# Done nullspace compression. Network size: 33 metabolites and 53 reactions ( 11 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Start reduced row echelon form calculations 2 . This may take a while
# Done echelon compression. Network size: 27 metabolites and 53 reactions ( 11 reversible )
# *** Compression round: 2 ***
# Start deadend compression...
# Done deadend compression. Network size: 27 metabolites and 53 reactions ( 11 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 27 metabolites and 53 reactions ( 11 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Done nullspace compression. Network size: 27 metabolites and 53 reactions ( 11 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Done echelon compression. Network size: 27 metabolites and 53 reactions ( 11 reversible )
# *** COMPRESSIONS DONE after: 2 rounds ***
# ========================================================================
# Compressed network size: 53 reactions ( 9 reversible ) and 27 metabolites.
# Writing files
#
#                     .-.
#                   /  oo
#    EFMlrs         \ -,_)
#              _..._| \ `-<
#         {} ." .__.\' |
#        {} (         /`\
#        {}(`´------´   /
#           `----------´
#    finished compressions
#
#
# ✅ Exported model_v2 to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/processed/sbml_files/ecolicore_model_v2.xml
# 🚀 Running efmlrs_pre on ecolicore_model_v2.xml...
#
#            EFMlrs     __
#     (\   .-.   .-.   /_")
#      \\_//^\\_//^\\_//
#       `"´   `"´   `"´
#      start compressions
#
# Ignoring compartments: None
# The following metabolites are orphans (not involved in any reaction) and will be removed from the model
# ['mal__L_e', 'fum_e']
# no empty reactions
# Checking for additional bounds
# Found 4 additional bounds:
# Lower bound: 8.39 for reaction ATPM
# Upper bound: 5.0 for reaction EX_fru_e_rev
# Upper bound: 10.0 for reaction EX_glc__D_e_rev
# Upper bound: 5.0 for reaction EX_gln__L_e_rev
# Uncompressed network size: 96 reactions ( 12 reversible ) and 74 metabolites.
# ========================================================================
# START COMPRESSIONS
# *** Compression round: 1 ***
# Start deadend compression...
# Done deadend compression. Network size: 74 metabolites and 96 reactions ( 12 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 38 metabolites and 60 reactions ( 12 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Start null space compressions round 2 . This may take a while
# Done nullspace compression. Network size: 36 metabolites and 57 reactions ( 12 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Start reduced row echelon form calculations 2 . This may take a while
# Done echelon compression. Network size: 30 metabolites and 57 reactions ( 12 reversible )
# *** Compression round: 2 ***
# Start deadend compression...
# Done deadend compression. Network size: 30 metabolites and 57 reactions ( 12 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 30 metabolites and 57 reactions ( 12 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Done nullspace compression. Network size: 30 metabolites and 57 reactions ( 12 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Done echelon compression. Network size: 30 metabolites and 57 reactions ( 12 reversible )
# *** COMPRESSIONS DONE after: 2 rounds ***
# ========================================================================
# Compressed network size: 57 reactions ( 10 reversible ) and 30 metabolites.
# Writing files
#
#                     .-.
#                   /  oo
#    EFMlrs         \ -,_)
#              _..._| \ `-<
#         {} ." .__.\' |
#        {} (         /`\
#        {}(`´------´   /
#           `----------´
#    finished compressions
#
#
# ✅ Exported model_v3 to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/processed/sbml_files/ecolicore_model_v3.xml
# 🚀 Running efmlrs_pre on ecolicore_model_v3.xml...
#
#            EFMlrs     __
#     (\   .-.   .-.   /_")
#      \\_//^\\_//^\\_//
#       `"´   `"´   `"´
#      start compressions
#
# Ignoring compartments: None
# The following metabolites are orphans (not involved in any reaction) and will be removed from the model
# ['mal__L_e']
# no empty reactions
# Checking for additional bounds
# Found 5 additional bounds:
# Lower bound: 8.39 for reaction ATPM
# Upper bound: 5.0 for reaction EX_fru_e_rev
# Upper bound: 5.0 for reaction EX_fum_e_rev
# Upper bound: 10.0 for reaction EX_glc__D_e_rev
# Upper bound: 5.0 for reaction EX_gln__L_e_rev
# Uncompressed network size: 99 reactions ( 16 reversible ) and 76 metabolites.
# ========================================================================
# START COMPRESSIONS
# *** Compression round: 1 ***
# Start deadend compression...
# Done deadend compression. Network size: 76 metabolites and 99 reactions ( 16 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 42 metabolites and 65 reactions ( 16 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Start null space compressions round 2 . This may take a while
# Done nullspace compression. Network size: 38 metabolites and 60 reactions ( 16 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Start reduced row echelon form calculations 2 . This may take a while
# Done echelon compression. Network size: 32 metabolites and 60 reactions ( 16 reversible )
# *** Compression round: 2 ***
# Start deadend compression...
# Done deadend compression. Network size: 32 metabolites and 60 reactions ( 16 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 32 metabolites and 60 reactions ( 16 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Done nullspace compression. Network size: 32 metabolites and 60 reactions ( 16 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Done echelon compression. Network size: 32 metabolites and 60 reactions ( 16 reversible )
# *** COMPRESSIONS DONE after: 2 rounds ***
# ========================================================================
# Compressed network size: 60 reactions ( 12 reversible ) and 32 metabolites.
# Writing files
#
#                     .-.
#                   /  oo
#    EFMlrs         \ -,_)
#              _..._| \ `-<
#         {} ." .__.\' |
#        {} (         /`\
#        {}(`´------´   /
#           `----------´
#    finished compressions
#
#
# ✅ Exported model_v4 to /Users/Luca/Desktop/Thesis_Rep/GitHub_Repo/data/processed/sbml_files/ecolicore_model_v4.xml
# 🚀 Running efmlrs_pre on ecolicore_model_v4.xml...
#
#            EFMlrs     __
#     (\   .-.   .-.   /_")
#      \\_//^\\_//^\\_//
#       `"´   `"´   `"´
#      start compressions
#
# Ignoring compartments: None
# no empty reactions
# Checking for additional bounds
# Found 6 additional bounds:
# Lower bound: 8.39 for reaction ATPM
# Upper bound: 5.0 for reaction EX_fru_e_rev
# Upper bound: 5.0 for reaction EX_fum_e_rev
# Upper bound: 10.0 for reaction EX_glc__D_e_rev
# Upper bound: 5.0 for reaction EX_gln__L_e_rev
# Upper bound: 5.0 for reaction EX_mal__L_e_rev
# Uncompressed network size: 102 reactions ( 16 reversible ) and 78 metabolites.
# ========================================================================
# START COMPRESSIONS
# *** Compression round: 1 ***
# Start deadend compression...
# Done deadend compression. Network size: 78 metabolites and 102 reactions ( 16 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 43 metabolites and 67 reactions ( 16 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Start null space compressions round 2 . This may take a while
# Done nullspace compression. Network size: 39 metabolites and 62 reactions ( 16 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Start reduced row echelon form calculations 2 . This may take a while
# Done echelon compression. Network size: 33 metabolites and 62 reactions ( 16 reversible )
# *** Compression round: 2 ***
# Start deadend compression...
# Done deadend compression. Network size: 33 metabolites and 62 reactions ( 16 reversible )
# Start many2one compression...
# Done many2one compression. Network size: 33 metabolites and 62 reactions ( 16 reversible )
# Start nullspace compression...
# Start null space compressions round 1 . This may take a while
# Done nullspace compression. Network size: 33 metabolites and 62 reactions ( 16 reversible )
# Start echelon compressions...
# Start reduced row echelon form calculations 1 . This may take a while
# Done echelon compression. Network size: 33 metabolites and 62 reactions ( 16 reversible )
# *** COMPRESSIONS DONE after: 2 rounds ***
# ========================================================================
# Compressed network size: 62 reactions ( 12 reversible ) and 33 metabolites.
# Writing files
#
#                     .-.
#                   /  oo
#    EFMlrs         \ -,_)
#              _..._| \ `-<
#         {} ." .__.\' |
#        {} (         /`\
#        {}(`´------´   /
#           `----------´
#    finished compressions
